# %%
class Yeuem:
    def __init__(self, name, nangluong):
        self.name = name
        self.nangluong = nangluong

    def tancong(self, target):
        self.nangluong = self.nangluong + target
em = Yeuem("Em", 100)
em.tancong(10)
print(f"nang luong con lai: {em.nangluong}, ten em: {em.name}")
# Out:
# nang luong con lai: 110, ten em: Em

# %%
anh = Yeuem("Anh", 150)
anh.tancong(20)
print(f"nang luong con lai: {anh.nangluong}, ten anh: {anh.name}")
# Out:
# nang luong con lai: 170, ten anh: Anh

# %%
#em la ai

# %%
#tinh yeu la gi, cuoc song gia bao nhieu

# %%
#christmas is coming

# %%
#nang mua
